# %%
# %load_ext autoreload
# %autoreload 2
import cv2 
import numpy as np
import pywt
import difflib
import matplotlib.pyplot as plt
import WatermarkOperation as wd
import Attack as atk
# %matplotlib inline

image = cv2.imread("./image/cover.png",cv2.IMREAD_GRAYSCALE)
np.random.seed(261025)
imageAftWav=pywt.wavedec2(image,"db4",mode="periodization",level=3,axes=(-2, -1))
hl3=imageAftWav[1][0]
t2=200
t1=115
wat_stored=wd.embedWatQuan(hl3,t1,t2)           
imageAftIdwt=pywt.waverec2(imageAftWav,"db4",mode="periodization",axes=(-2, -1))
pic=(imageAftIdwt).astype(np.uint8)
imageAftWav2=pywt.wavedec2(pic,"db4",mode="periodization",level=3,axes=(-2, -1))
hl3=imageAftWav2[1][0]
base_ratio=wd.detectWatQuan(wat_stored,hl3,t1,t2)

#beforeWater
imageAftWav2=pywt.wavedec2(image,"db4",mode="periodization",level=3,axes=(-2, -1))
hl3=imageAftWav2[1][0]
before_ratio=wd.detectWatQuan(wat_stored,hl3,t1,t2)
# blur
blurred=cv2.GaussianBlur(pic,(5,5),0)
imageAftWav2=pywt.wavedec2(blurred,"db4",mode="periodization",level=3,axes=(-2, -1))
hl3=imageAftWav2[1][0]
blurred_ratio=wd.detectWatQuan(wat_stored,hl3,t1,t2)
#sharpen
sharpened=atk.sharpen(pic)
imageAftWav2=pywt.wavedec2(sharpened,"db4",mode="periodization",level=3,axes=(-2, -1))
hl3=imageAftWav2[1][0]
sharpened_ratio=wd.detectWatQuan(wat_stored,hl3,t1,t2)
#rotate
rotated=atk.rotate(pic)
imageAftWav2=pywt.wavedec2(rotated,"db4",mode="periodization",level=3,axes=(-2, -1))
hl3=imageAftWav2[1][0]
rotated_ratio=wd.detectWatQuan(wat_stored,hl3,t1,t2)
#crop
cropped=atk.crop(pic)
imageAftWav2=pywt.wavedec2(cropped,"db4",mode="periodization",level=3,axes=(-2, -1))
hl3=imageAftWav2[1][0]
cropped_ratio=wd.detectWatQuan(wat_stored,hl3,t1,t2)
#compress
cv2.imwrite("./image/ReferenceImg/compressed.jpg", pic, [cv2.IMWRITE_JPEG_QUALITY, 50])
compressed=cv2.imread("./image/ReferenceImg/compressed.jpg",cv2.IMREAD_GRAYSCALE)
imageAftWav2=pywt.wavedec2(compressed,"db4",mode="periodization",level=3,axes=(-2, -1))
hl3=imageAftWav2[1][0]
compressed_ratio=wd.detectWatQuan(wat_stored,hl3,t1,t2)
# salt and pepper
saltAndPep=atk.saltAndPepper(pic,0.95)
imageAftWav2=pywt.wavedec2(saltAndPep,"db4",mode="periodization",level=3,axes=(-2, -1))
hl3=imageAftWav2[1][0]
saltAndPep_ratio=wd.detectWatQuan(wat_stored,hl3,t1,t2)


cv2.imwrite("./image/ReferenceImg/blurred.jpg",blurred,[cv2.IMWRITE_JPEG_QUALITY, 100])
cv2.imwrite("./image/ReferenceImg/sharpened.jpg",sharpened,[cv2.IMWRITE_JPEG_QUALITY, 100])
cv2.imwrite("./image/ReferenceImg/rotated.jpg",rotated,[cv2.IMWRITE_JPEG_QUALITY, 100])
cv2.imwrite("./image/ReferenceImg/cropped.jpg",cropped,[cv2.IMWRITE_JPEG_QUALITY, 100])
#cv2.imwrite("./image/ReferenceImg/compressed.jpg",compressed,[cv2.IMWRITE_JPEG_QUALITY, 100])
cv2.imwrite("./image/ReferenceImg/saltAndPep.jpg",saltAndPep,[cv2.IMWRITE_JPEG_QUALITY, 100])
cv2.imwrite("./image/ReferenceImg/beforeAttack.jpg",pic,[cv2.IMWRITE_JPEG_QUALITY, 100])

print(base_ratio)
print(abs(blurred_ratio-base_ratio)/abs(before_ratio-base_ratio))
print(abs(sharpened_ratio-base_ratio)/abs(before_ratio-base_ratio))
print(abs(rotated_ratio-base_ratio)/abs(before_ratio-base_ratio))
print(abs(cropped_ratio-base_ratio)/abs(before_ratio-base_ratio))
print(abs(compressed_ratio-base_ratio)/abs(before_ratio-base_ratio))
print(abs(saltAndPep_ratio-base_ratio)/abs(before_ratio-base_ratio))



#cv2.waitKey()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.9806763285024155
# 3.5130972592772216
# 3.1121011491570867
# 0.387654809907834
# 0.42009141044043274
# 0.06797235023041497
# 0.5230414746543781
